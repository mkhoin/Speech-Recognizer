# %%
#Resultados performance treino com limpa e 30% sem stratified
# %matplotlib inline
#import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))

f_0 = [75.22, 47.44, 38.14, 36.13, 33.72, 26.59, 27.23, 27.74,25.12, 24.54, 20.70]
f_30 = [39.98, 70.50, 72.55, 71.15, 69.57, 68.27, 62.65, 58.57, 60.81, 55.98, 54.34]
f0_30 = [68.51, 66.72, 71.22, 64.42, 60.11, 59.18, 54.43, 51.58, 51.29, 51.32, 47.21]


nvl_reverb = range(0, 110, 10)
limit = [60, 60,60,60,60,60,60,60,60,60,60]
sigma0 = [16.33, 10.76, 7.58, 7.85, 6.92, 7.06, 5.37, 9.82, 6.06, 7.35, 7.56]
sigma30 = [5.28, 12.84, 15.21, 16.19, 17.32, 15.14, 16.82, 14.43, 15.25, 14.05,14.16]
sigma0_30 = [14.03, 11.63, 14.37, 14.84, 15.43, 16.58, 15.02, 14.08, 15.38, 11.06, 11.25]

print "fold F, 12 states of HMM"

#plt.subplot(211)
plt.plot(nvl_reverb, f_0,"-.", label="Treino com R0", linewidth=3.0)
plt.plot(nvl_reverb, f_30, '--', label="Treino com R30", linewidth=3.0)
plt.plot(nvl_reverb, f0_30, 'r-', label="Treino com R0+R30", linewidth=3.0)
#plt.plot(nvl_reverb, f_0,"ks", label="Train with R0")
#plt.plot(nvl_reverb, f_30, 'k^', label="Train with R30")
#plt.plot(nvl_reverb, f0_30, 'ko', label="Train with R0 and R30")
#plt.plot(nvl_reverb,limit , 'k:')
#plt.errorbar(nvl_reverb, f_0, yerr=sigma0, marker='s')
#plt.errorbar(nvl_reverb, f_30, yerr=sigma30, marker='^')
#plt.errorbar(nvl_reverb, f0_30, yerr=sigma0_30, marker='')

plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=3, mode="expand", borderaxespad=0., fontsize=12)

#plt.legend(bbox_to_anchor=(.05, 0.5), loc='best')
plt.xlabel(u'Níveis de reverberação [%]', fontsize=16)
plt.ylabel('F-score [%]', fontsize=16)
fig.savefig("performance_30.png",bbox_extra_artists='legend')
plt.show()

# %%
#Resultados performance treino com limpa e 30% sem stratified
# %matplotlib inline
#import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))

f_0 = [75.22, 47.44, 38.14, 36.13, 33.72, 26.59, 27.23, 27.74,25.12, 24.54, 20.70]
f0_10 = [68.74, 72.66, 67.42, 64.69, 58.75, 53.92, 47.98, 44.55, 44.46, 40.41, 38.38]
f_10 = [39.02, 73.74, 72.06, 68.07, 64.58, 56.77, 55.08, 49.55, 45.17, 45.89, 43.98]


nvl_reverb = range(0, 110, 10)
limit = [60, 60,60,60,60,60,60,60,60,60,60]
sigma0 = [16.33, 10.76, 7.58, 7.85, 6.92, 7.06, 5.37, 9.82, 6.06, 7.35, 7.56]
sigma10 = [11.35, 14.83, 15.75, 16.76, 13.04, 13.25, 12.32, 12.52, 11.00, 12.61, 12.87]
sigma0_10 = [18.61, 14.70, 16.34, 15.21, 13.45, 12.65, 11.50, 12.64, 8.90, 10.45, 9.30]

print "fold F, 12 states of HMM"

#plt.subplot(211)
plt.plot(nvl_reverb, f_0,"-.", label="Treino com R0", linewidth=3.0)
plt.plot(nvl_reverb, f_10, '--', label="Treino com R10", linewidth=3.0)
plt.plot(nvl_reverb, f0_10, 'r-', label="Treino com R0+R10", linewidth=3.0)
#plt.plot(nvl_reverb, f_0,"ks", label="Train with R0")
#plt.plot(nvl_reverb, f_10, 'k^', label="Train with R10")
#plt.plot(nvl_reverb, f0_10, 'ko', label="Train with R0 and R10")
#plt.plot(nvl_reverb,limit , 'k:')
#plt.errorbar(nvl_reverb, f_0, yerr=sigma0, marker='s')
#plt.errorbar(nvl_reverb, f_10, yerr=sigma10, marker='')
#plt.errorbar(nvl_reverb, f0_10, yerr=sigma0_10, marker='')

plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=3, mode="expand", borderaxespad=0., fontsize=12)

#plt.legend(bbox_to_anchor=(.05, 0.5), loc='best')
plt.xlabel(u'Níveis de reverberação [%]', fontsize=16)
plt.ylabel('F-score [%]', fontsize=16)
fig.savefig("performance_10.png",bbox_extra_artists='legend')#, bbox_inches="none")
plt.show()

# %%
#Resultados performance treino com limpa e 70% com stratified
# %matplotlib inline
#import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))

f_0 = [75.22, 47.44, 38.14, 36.13, 33.72, 26.59, 27.23, 27.74,25.12, 24.54, 20.70]
f_70 = [16.66, 45.65, 52.84, 60.21, 70.11, 73.00, 71.91, 73.42, 72.38, 71.07, 70.61]
f0_70 = [66.75, 57.06, 57.15, 57.28, 56.88, 60.74,58.92, 60.26, 58.82, 58.15, 59.36]


nvl_reverb = range(0, 110, 10)
#limit = [60, 60,60,60,60,60,60,60,60,60,60]
#sigma0 = []
#sigma70 = []
#sigma0_70 = []

print "fold F, 12 states of HMM"

#plt.subplot(211)
plt.plot(nvl_reverb, f_0,"-.", label="Treino com R0", linewidth=3.0)
plt.plot(nvl_reverb, f_70, '--', label="Treino com R70", linewidth=3.0)
plt.plot(nvl_reverb, f0_70, 'r-', label="Treino com R0+R70", linewidth=3.0)
#plt.plot(nvl_reverb, f_0,"ks", label="Train with R0")
#plt.plot(nvl_reverb, f_10, 'k^', label="Train with R10")
#plt.plot(nvl_reverb, f0_10, 'ko', label="Train with R0 and R10")
#plt.plot(nvl_reverb,limit , 'k:')
#plt.errorbar(nvl_reverb, f_0, yerr=sigma0, marker='s')
#plt.errorbar(nvl_reverb, f_70, yerr=sigma10, marker='')
#plt.errorbar(nvl_reverb, f0_70, yerr=sigma0_10, marker='')

plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=3, mode="expand", borderaxespad=0., fontsize=12)

#plt.legend(bbox_to_anchor=(.05, 0.5), loc='best')
plt.xlabel(u'Níveis de reverberação [%]', fontsize=16)
plt.ylabel('F-score [%]', fontsize=16)

fig.savefig("performance_70.png",bbox_extra_artists='legend')
plt.show()

# %%
#Resultados performance treino com limpa, 30% e 70% com stratified
# %matplotlib inline
#import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6.5))

f0_10 = [68.74, 72.66, 67.42, 64.69, 58.75, 53.92, 47.98, 44.55, 44.46, 40.41, 38.38]
f0_30 = [68.51, 66.72, 71.22, 64.42, 60.11, 59.18, 54.43, 51.58, 51.29, 51.32, 47.21]
f0_70 = [66.75, 57.06, 57.15, 57.28, 56.88, 60.74,58.92, 60.26, 58.82, 58.15, 59.36]
f0_30_70 = [62.08, 63.19, 68.44, 67.12,66.33, 63.17, 63.00, 60.06, 59.34, 56.78, 57.02]

nvl_reverb = range(0, 110, 10)
#limit = [60, 60,60,60,60,60,60,60,60,60,60]
#sigma0 = []
#sigma70 = []
#sigma0_70 = []

print "fold F, 12 states of HMM"

#plt.subplot(211)
plt.plot(nvl_reverb, f0_10, ':', label="Treino com R0+R10", linewidth=3.0)
plt.plot(nvl_reverb, f0_30, '-.', label="Treino com R0+R30", linewidth=3.0)
plt.plot(nvl_reverb, f0_70, '--m', label="Treino com R0+R70", linewidth=3.0)
plt.plot(nvl_reverb, f0_30_70, '-r', label="Treino com R0+R30+R70", linewidth=3.0)
#plt.plot(nvl_reverb, f_0,"ks", label="Train with R0")
#plt.plot(nvl_reverb, f_10, 'k^', label="Train with R10")
#plt.plot(nvl_reverb, f0_10, 'ko', label="Train with R0 and R10")
#plt.plot(nvl_reverb,limit , 'k:')
#plt.errorbar(nvl_reverb, f_0, yerr=sigma0, marker='s')
#plt.errorbar(nvl_reverb, f_70, yerr=sigma10, marker='')
#plt.errorbar(nvl_reverb, f0_70, yerr=sigma0_10, marker='')

plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=2, mode="expand", borderaxespad=0., fontsize=12)

#plt.legend(bbox_to_anchor=(.05, 0.5), loc='best')
plt.xlabel(u'Níveis de reverberação [%]', fontsize=16)
plt.ylabel('F-score [%]', fontsize=16)
fig.savefig("performance_MC.png",bbox_extra_artists='legend')
plt.show()
